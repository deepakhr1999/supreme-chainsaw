# %%
from fastmcp import Client
async with Client("http://localhost:8000/mcp") as client:
    result = await client.call_tool("greet", arguments={"name": "deepak"})
    print(result)
# Out:
# CallToolResult(content=[TextContent(type='text', text='Hello, deepak!', annotations=None, meta=None)], structured_content={'result': 'Hello, deepak!'}, meta={'fastmcp': {'wrap_result': True}}, data='Hello, deepak!', is_error=False)

# %%
from fastmcp import Client
async with Client("http://localhost:8000/mcp") as client:
    result = await client.call_tool("get_workouts", arguments={"page": 1, "page_size": 2})
    print(result)
# Out:
# CallToolResult(content=[TextContent(type='text', text='{"page":1,"page_count":6,"workouts":[{"id":"783f7431-12ef-4328-bd75-784b91008dfe","title":"Shoulder","routine_id":"9eefd4e9-9e49-43df-94ca-1d89405bf568","description":"","start_time":"2026-04-14T00:53:11+00:00","end_time":"2026-04-14T01:55:13+00:00","updated_at":"2026-04-14T01:55:33.669Z","created_at":"2026-04-14T01:55:33.669Z","exercises":[{"index":0,"title":"Seated Shoulder Press (Machine)","notes":"","exercise_template_id":"9237BAD1","superset_id":null,"sets":[{"index":0,"type":"normal","weight_kg":31.75150366049478,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":1,"type":"normal","weight_kg":31.75150366049478,"reps":7,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":2,"type":"normal","weight_kg":31.75150366049478,"reps":6,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null}]},{"index":1,"title":"Shrug (Dumbbell)","notes":"","exercise_template_id":"ABEC557F","superset_id":null,"sets":[{"index":0,"type":"normal","weight_kg":31.75150366049478,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":1,"type":"normal","weight_kg":31.75150366049478,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":2,"type":"normal","weight_kg":31.75150366049478,"reps":12,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null}]},{"index":2,"title":"Single Arm Lateral Raise (Cable)","notes":"","exercise_template_id":"DE68C825","superset_id":null,"sets":[{"index":0,"type":"normal","weight_kg":4.535929094356398,"reps":12,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":1,"type":"normal","weight_kg":4.535929094356398,"reps":12,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":2,"type":"normal","weight_kg":4.535929094356398,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":3,"type":"normal","weight_kg":4.535929094356398,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":4,"type":"normal","weight_kg":4.535929094356398,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":5,"type":"normal","weight_kg":4.535929094356398,"reps":7,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null}]},{"index":3,"title":"Rear Delt Reverse Fly (Machine)","notes":"","exercise_template_id":"D8281C62","superset_id":null,"sets":[{"index":0,"type":"normal","weight_kg":27.215574566138386,"reps":10,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":1,"type":"normal","weight_kg":31.75150366049478,"reps":7,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":2,"type":"normal","weight_kg":31.75150366049478,"reps":7,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null}]},{"index":4,"title":"Triceps Extension (Machine)","notes":"","exercise_template_id":"3092FADD","superset_id":null,"sets":[{"index":0,"type":"normal","weight_kg":18.14371637742559,"reps":8,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":1,"type":"normal","weight_kg":18.14371637742559,"reps":8,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null},{"index":2,"type":"normal","weight_kg":18.14371637742559,"reps":6,"distance_meters":null,"duration_seconds":null,"rpe":null,"custom_metric":null}]}]},{"id":"609023cb-7c5e-4755-81dc-1ab31d36223d","title":"Evening workout 🏋️","routine_id":null,"description":"","start_time":"2026-04-12T22:07:13+00:00","end_time":"2026-04-12T23:11:12+00:00","updated_at":"2026-04-12T23:11:33.688Z","created_at":"2026-04-12T23:11:33.688Z","exercises":[{"index":0,"title":"Chest Press (Machine)","notes":"","exercis ...

# %%
from fastmcp import Client
async with Client("http://localhost:8000/mcp") as client:
    result = await client.call_tool("body_measurements", arguments={"page":1,"page_size":1})
    print(result)
# Out:
# CallToolResult(content=[TextContent(type='text', text='{"page":1,"page_count":1,"body_measurements":[]}', annotations=None, meta=None)], structured_content={'result': '{"page":1,"page_count":1,"body_measurements":[]}'}, meta={'fastmcp': {'wrap_result': True}}, data='{"page":1,"page_count":1,"body_measurements":[]}', is_error=False)
